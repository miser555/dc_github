# %%
import requests
import pandas as pd

# %%
r = requests.get('https://api.github.com/search/repositories?q=django+language:python&sort=stars&order=desc',
                 auth=('miser555', 'pypy66640772'))

# %%
r.status_code
# Out:
# 200

# %%
records = r.json()
records
# Out:
# {'incomplete_results': False,
#  'items': [{'archive_url': 'https://api.github.com/repos/django/django/{archive_format}{/ref}',
#    'assignees_url': 'https://api.github.com/repos/django/django/assignees{/user}',
#    'blobs_url': 'https://api.github.com/repos/django/django/git/blobs{/sha}',
#    'branches_url': 'https://api.github.com/repos/django/django/branches{/branch}',
#    'clone_url': 'https://github.com/django/django.git',
#    'collaborators_url': 'https://api.github.com/repos/django/django/collaborators{/collaborator}',
#    'comments_url': 'https://api.github.com/repos/django/django/comments{/number}',
#    'commits_url': 'https://api.github.com/repos/django/django/commits{/sha}',
#    'compare_url': 'https://api.github.com/repos/django/django/compare/{base}...{head}',
#    'contents_url': 'https://api.github.com/repos/django/django/contents/{+path}',
#    'contributors_url': 'https://api.github.com/repos/django/django/contributors',
# ...

# %%
data = {x :x for x in records.items() if x}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-8708179c21a8> in <module>()
# ----> 1 data = {x :x for x in records.items() if x}
#
# <ipython-input-5-8708179c21a8> in <dictcomp>(.0)
# ----> 1 data = {x :x for x in records.items() if x}
#
# TypeError: unhashable type: 'list'

# %%
data = {x :x for x in records if x}
data
# Out:
# {'incomplete_results': 'incomplete_results',
#  'items': 'items',
#  'total_count': 'total_count'}

# %%
rec = [r for r in records]
rec
# Out:
# ['incomplete_results', 'total_count', 'items']

# %%
from pandas.io.json import json_normalize

# %%
result = json_normalize(records, 'items', 'incomplete_results', 'total_count')

# %%
result
# Out:
#                                           archive_url  \
# 0   https://api.github.com/repos/django/django/{ar...
# 1   https://api.github.com/repos/tomchristie/djang...
# 2   https://api.github.com/repos/divio/django-cms/...
# 3   https://api.github.com/repos/jazzband/django-d...
# 4   https://api.github.com/repos/torchbox/wagtail/...
# 5   https://api.github.com/repos/django-tastypie/d...
# 6   https://api.github.com/repos/taigaio/taiga-bac...
# 7   https://api.github.com/repos/django-extensions...
# 8   https://api.github.com/repos/eudicots/Cactus/{...
# 9   https://api.github.com/repos/stephenmcd/mezzan...
# 10  https://api.github.com/repos/pennersr/django-a...
# 11  https://api.github.com/repos/django-crispy-for...
# 12  https://api.github.com/repos/omab/django-socia...
# 13  https://api.github.com/repos/django-oscar/djan...
# 14  https://api.github.com/repos/django-haystack/d...
# 15  https://api.github.com/repos/pinax/pinax/{arch...
# ...
